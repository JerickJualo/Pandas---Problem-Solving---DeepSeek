# %%
import pandas as pd

series_df = pd.read_csv(r'C:\Users\User\OneDrive\Documents\Pandas - Problem Solving - DeepSeek\Data Sets\product_sales_2024.csv')

# %% [markdown]
# # Dataset: "Product Sales 2024"
# # File name: product_sales_2024.csv
#
# Description:
#
# This dataset contains daily sales information for various products. You will load it into a Pandas Series or extract Series columns from it. The data includes product names, categories, units sold, price per unit, and total revenue.
#
# Topics Covered from Your Links:
#
# * Creating a Series from lists, dictionaries, and scalar values
# * Understanding Series attributes like index, values, dtype, size, and shape
# * Indexing and selecting data using [ ], .loc[], .iloc[], .at[], and .iat[]
# * Slicing a Series using labels and integer positions
# * Performing arithmetic operations on Series (scalar and element‑wise)
# * Basic Series functionality like head(), tail(), and describe()
# * Converting a Series to Python lists, NumPy arrays, dictionaries, and DataFrames
# * Working with Index objects and basic alignment

# %% [markdown]
# # Easy Level - Series

# %% [markdown]
# Problem 1 – Create a Series from a DataFrame Column
# Task:
# Read the CSV file into a DataFrame, then extract the units_sold column as a Pandas Series named sales. Print the Series.
#
# Pandas Concept Used:
# pd.read_csv() and selecting a column as a Series.
#
# # Expected Output (terminal):
#
# 0     15
# 1     22
# 2      8
# 3     30
# 4     12
# 5     18
# ...   ...
# 25    23
# 26    17
# 27     9
# 28    33
# 29    11
# Name: units_sold, dtype: int64

# %% [markdown]
# Problem 2 – Display the First 5 Rows of a Series
# Task:
# Using the sales Series from Problem 1, print only the first five rows.
#
# Pandas Concept Used:
# Series.head()
#
# # Expected Output (terminal):
# 0    15
# 1    22
# 2     8
# 3    30
# 4    12
# Name: units_sold, dtype: int64

# %% [markdown]
# Problem 3 – Display the Last 3 Rows of a Series
# Task:
# Using the sales Series, print only the last three rows.
#
# Pandas Concept Used:
# Series.tail()
#
# # Expected Output (terminal):
# 27     9
# 28    33
# 29    11
# Name: units_sold, dtype: int64

# %% [markdown]
# Problem 4 – Check the Data Type of a Series
# Task:
# Print the data type of the sales Series.
#
# Pandas Concept Used:
# Series.dtype attribute
#
# # Expected Output (terminal):
# int64

# %% [markdown]
# Problem 5 – Get the Index Object of a Series
# Task:
# Print the index object of the sales Series.
#
# Pandas Concept Used:
# Series.index attribute
#
# # Expected Output (terminal):
#
# RangeIndex(start=0, stop=30, step=1)

# %% [markdown]
# Problem 6 – Retrieve the Underlying NumPy Array of Values
# Task:
# Print the underlying NumPy array of values from the sales Series.
#
# Pandas Concept Used:
# Series.values attribute
#
# # Expected Output (terminal):
#
# [15 22  8 30 12 18 25  5 35  9 20 28 11 40  6 16 32  7 38 14 10 19 13 45
#   8 23 17  9 33 11]

# %% [markdown]
# Problem 7 – Find the Number of Elements in a Series
# Task:
# Print the total number of elements in the sales Series.
#
# Pandas Concept Used:
# Series.size attribute
#
# # Expected Output (terminal):
#
# 30

# %% [markdown]
# Problem 8 – Find the Shape (Dimensions) of a Series
# Task:
# Print the shape of the sales Series as a tuple.
#
# Pandas Concept Used:
# Series.shape attribute
#
# # Expected Output (terminal):
#
# (30,)

# %% [markdown]
# Problem 9 – Select a Single Value by Integer Position
# Task:
# Create a Series named price from the price_per_unit column of the DataFrame. Then print the value at integer position 4 (the fifth element).
#
# Pandas Concept Used:
# Series.iloc[] or Series.iat[]
#
# # Expected Output (terminal):
#
# 18.5

# %% [markdown]
# Problem 10 – Slice a Series Using Integer Positions
# Task:
# Using the sales Series, print a slice from position 10 up to (but not including) position 15.
#
# Pandas Concept Used:
# Integer‑based slicing with [start:end]
#
# # Expected Output (terminal):
#
# 10    20
# 11    28
# 12    11
# 13    40
# 14     6
# Name: units_sold, dtype: int64

# %% [markdown]
# Problem 11 – Filter a Series with a Boolean Condition
# Task:
# Print only the values from the sales Series that are greater than 25.
#
# Pandas Concept Used:
# Boolean indexing Series[Series > value]
#
# # Expected Output (terminal):
#
# 3     30
# 6     25
# 7     35
# 11    28
# 13    40
# 16    32
# 18    38
# 23    45
# 28    33
# Name: units_sold, dtype: int64

# %% [markdown]
# Problem 12 – Perform Scalar Addition on a Series
# Task:
# Print a new Series where 3 is added to every value in the sales Series.
#
# Pandas Concept Used:
# Scalar addition Series + scalar
#
# # Expected Output (terminal):
# 0     18
# 1     25
# 2     11
# 3     33
# 4     15
# 5     21
# 6     28
# ...   ...
# 21    22
# 22    16
# 23    48
# 24    11
# 25    26
# 26    20
# 27    12
# 28    36
# 29    14
# Name: units_sold, dtype: int64

# %% [markdown]
# Problem 13 – Calculate the Sum of All Values in a Series
# Task:
# Print the total sum of the sales Series.
#
# Pandas Concept Used:
# Series.sum()
#
# # Expected Output (terminal):
# 578

# %% [markdown]
# Problem 14 – Convert a Series to a Python List
# Task:
# Convert the sales Series to a Python list and print the list.
#
# Pandas Concept Used:
# Series.to_list()
#
# # Expected Output (terminal):
# [15, 22, 8, 30, 12, 18, 25, 5, 35, 9, 20, 28, 11, 40, 6, 16, 32, 7, 38, 14, 10, 19, 13, 45, 8, 23, 17, 9, 33, 11]

# %% [markdown]
# Problem 15 – Generate Descriptive Statistics of a Series
# Task:
# Print the descriptive statistics (count, mean, std, min, quartiles, max) for the price Series (the price_per_unit column).
#
# Pandas Concept Used:
# Series.describe()
#
# # Expected Output (terminal):
# count    30.000000
# mean     14.046667
# std       7.502876
# min       5.750000
# 25%       8.500000
# 50%      12.990000
# 75%      18.500000
# max      24.990000
# Name: price_per_unit, dtype: float64
