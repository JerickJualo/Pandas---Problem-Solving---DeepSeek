# %%
import pandas as pd

regional_df = pd.read_csv(r'C:\Users\Admin\OneDrive\Documents\Pandas - Problem Solving - DeepSeek\Pandas---Problem-Solving---DeepSeek\Data Sets\regional_sales_2024.csv')

# %% [markdown]
# # Pandas – Multi-Index & Binary Operations: Practice Set 1 (Easy)
# # Instructions:
#
# * Save the dataset as regional_sales_2024.csv in your working directory.
# * Write the Pandas code for each task to produce the exact terminal output shown.
# * Compare your output with the expected output to verify your solution.
#
# # File name: regional_sales_2024.csv
#
# # Description:
#
# This dataset contains quarterly sales records across 4 regions and 5 product categories. It includes units sold, revenue, target, profit margin, and store rating. With 40 rows, it is designed for practicing MultiIndex creation, indexing, sorting, renaming, and binary comparison/filtering operations.

# %% [markdown]
# # The Problems cover:
#
# # MultiIndex:
#
# * Creating MultiIndex using from_arrays(), from_tuples(), from_product(), from_frame()
# * Basic indexing with .loc[] on MultiIndex (by level, by tuple, by specific element)
# * Boolean indexing and slicing on MultiIndexed DataFrames
# * Renaming MultiIndex labels with rename(), rename_axis(), set_names()
# * Sorting MultiIndex with sort_index(), sort_index(level=)
#
# # Binary Operations:
#
# * Binary comparison operators (<, >, <=, >=, ==, !=)
# * Binary comparison functions (lt(), gt(), le(), ge(), eq(), ne())
# * Boolean indexing with .loc[], .iloc[] and boolean masks
# * Boolean masking with isin() and ~ (NOT) operator

# %% [markdown]
# Problem 1 – Create a MultiIndex Using from_arrays()
# Task:
# Read the CSV file into a DataFrame named df. Create a MultiIndex from the region and product_category columns using pd.MultiIndex.from_arrays(). Set this MultiIndex as the DataFrame's index with level names 'Region' and 'Product'. Print the first 6 rows.
#
# Pandas Concept Used:
# pd.MultiIndex.from_arrays(), df.set_index(), or direct df.index = ...
#
# # Expected Output (terminal):
#                        quarter  units_sold  revenue  target  profit_margin  store_rating
# Region Product
# North  Electronics           Q1          90    27000   25000           22.5           4.2
#        Electronics           Q2         100    30000   28000           24.1           4.5
#        Clothing              Q1         160    12000   11000           18.0           3.8
#        Clothing              Q2         170    12750   11500           16.5           3.9
#        Food                  Q1         260     7800    7500           12.0           4.0
#        Food                  Q2         270     8100    7800           13.5           4.2

# %%
mi_df = pd.MultiIndex.from_arrays([regional_df['region'],
                                    regional_df['product_category']],
                                    names = ['Region', 'Product'])
copy1_df = regional_df.copy()
copy1_df.index = mi_df

copy1_df = copy1_df.drop(columns=['region', 'product_category'])

print(copy1_df.head(6))
# Out:
#                    quarter  units_sold  revenue  target  profit_margin  \
# Region Product
# North  Electronics      Q1          90    27000   25000           22.5
#        Electronics      Q2         100    30000   28000           24.1
#        Clothing         Q1         160    12000   11000           18.0
#        Clothing         Q2         170    12750   11500           16.5
#        Food             Q1         260     7800    7500           12.0
#        Food             Q2         270     8100    7800           13.5
#
#                     store_rating
# Region Product
# North  Electronics           4.2
#        Electronics           4.5
#        Clothing              3.8
#        Clothing              3.9
#        Food                  4.0
#        Food                  4.2

# %% [markdown]
# Problem 2 – Create a MultiIndex Using from_tuples()
# Task:
# Read the CSV file into df. Create a list of tuples from the region and quarter columns for the first 8 rows. Then create a MultiIndex from those tuples using pd.MultiIndex.from_tuples() with names 'Region' and 'Quarter'. Assign it as the index of df.head(8). Print the resulting DataFrame showing only the product_category and revenue columns.
#
# Pandas Concept Used:
# pd.MultiIndex.from_tuples()
#
# # Expected Output (terminal):
#                   product_category  revenue
# Region Quarter
# North  Q1              Electronics    27000
#        Q2              Electronics    30000
#        Q1                 Clothing    12000
#        Q2                 Clothing    12750
#        Q1                     Food     7800
#        Q2                     Food     8100
#        Q1                     Home    17500
#        Q2                     Home    20000

# %%
copy2_df = regional_df.copy()
test = []

for x in copy2_df.itertuples():
    if x.Index < 8:
        test.append((x.region, x.quarter))

tuple_multi = pd.MultiIndex.from_tuples(test, names=['Region', 'Quarter'])

test_head_8 = copy2_df.head(8).copy()
test_head_8.index = tuple_multi

print(test_head_8.loc[:, ['product_category', 'revenue']])
# Out:
#                product_category  revenue
# Region Quarter
# North  Q1           Electronics    27000
#        Q2           Electronics    30000
#        Q1              Clothing    12000
#        Q2              Clothing    12750
#        Q1                  Food     7800
#        Q2                  Food     8100
#        Q1                  Home    17500
#        Q2                  Home    20000

# %% [markdown]
# Problem 3 – Create a MultiIndex Using from_product()
# Task:
# Use pd.MultiIndex.from_product() to create a MultiIndex from the Cartesian product of ['North', 'South'] (regions) and ['Electronics', 'Clothing', 'Food'] (products). Name the levels 'Region' and 'Product'. Print the resulting MultiIndex object.
#
# Pandas Concept Used:
# pd.MultiIndex.from_product()
#
# # Expected Output (terminal):
# MultiIndex([('North', 'Electronics'),
#             ('North',    'Clothing'),
#             ('North',        'Food'),
#             ('South', 'Electronics'),
#             ('South',    'Clothing'),
#             ('South',        'Food')],
#            names=['Region', 'Product'])

# %%
cart_product_index = [['North', 'South'],
                      ['Electronics', 'Clothing', 'Food']]

cart_final_index = pd.MultiIndex.from_product(cart_product_index, names=['Region', 'Product'])

cart_final_index
# Out:
# MultiIndex([('North', 'Electronics'),
#             ('North',    'Clothing'),
#             ('North',        'Food'),
#             ('South', 'Electronics'),
#             ('South',    'Clothing'),
#             ('South',        'Food')],
#            names=['Region', 'Product'])

# %% [markdown]
# Problem 4 – Create a MultiIndex Using from_frame()
# Task:
# Create a small DataFrame temp_df with columns 'Dept' and 'Team' containing the values [('Sales', 'A'), ('Sales', 'B'), ('HR', 'A')]. Use pd.MultiIndex.from_frame(temp_df) to create a MultiIndex from this DataFrame. Print the MultiIndex object.
#
# Pandas Concept Used:
# pd.MultiIndex.from_frame()
#
# # Expected Output (terminal):
# MultiIndex([('Sales', 'A'),
#             ('Sales', 'B'),
#             (  'HR', 'A')],
#            names=['Dept', 'Team'])

# %%
temp_df = pd.DataFrame([('Sales', 'A'), ('Sales', 'B'), ('HR', 'A')], columns=['Dept', 'Team'])

multi_index_df  = pd.MultiIndex.from_frame(temp_df)

multi_index_df
# Out:
# MultiIndex([('Sales', 'A'),
#             ('Sales', 'B'),
#             (   'HR', 'A')],
#            names=['Dept', 'Team'])

# %% [markdown]
# Problem 5 – Select All Rows for a Specific First-Level Label
# Task:
# Using the MultiIndexed DataFrame from Problem 1 (mi_df with index levels Region and Product), select and print all rows where the Region is 'South'.
#
# Pandas Concept Used:
# .loc[] for basic MultiIndex indexing by the first level
#
# # Expected Output (terminal):
#                     quarter  units_sold  revenue  target  profit_margin  store_rating
# Region Product
# South  Electronics       Q1          85    25500   24000           21.0           3.9
#        Electronics       Q2          90    27000   25000           22.0           4.0
#        Clothing          Q1         155    11625   10500           17.0           4.2
#        Clothing          Q2         160    12000   11000           18.0           4.3
#        Food              Q1         255     7650    7200           11.5           3.7
#        Food              Q2         260     7800    7400           12.5           3.9
#        Home              Q1          65    16250   15000           24.0           4.1
#        Home              Q2          70    17500   16000           25.0           4.2
#        Sports            Q1         105    12600   11500           18.5           3.8
#        Sports            Q2         110    13200   12000           19.5           3.9

# %%
copy1_df.loc[['South']].head(10)
# Out:
#                    quarter  units_sold  revenue  target  profit_margin  \
# Region Product
# South  Electronics      Q1          85    25500   24000           21.0
#        Electronics      Q2          90    27000   25000           22.0
#        Clothing         Q1         155    11625   10500           17.0
#        Clothing         Q2         160    12000   11000           18.0
#        Food             Q1         255     7650    7200           11.5
#        Food             Q2         260     7800    7400           12.5
#        Home             Q1          65    16250   15000           24.0
#        Home             Q2          70    17500   16000           25.0
#        Sports           Q1         105    12600   11500           18.5
#        Sports           Q2         110    13200   12000           19.5
#
#                     store_rating
# Region Product
# South  Electronics           3.9
#        Electronics           4.0
#        Clothing              4.2
# ...

# %% [markdown]
# Problem 6 – Select a Row Using a Tuple of Labels
# Task:
# Using the same MultiIndexed DataFrame, select and print the row with Region = 'East' and Product = 'Home' (both Q1 and Q2 rows).
#
# Pandas Concept Used:
# .loc[] with a tuple of level labels
#
# # Expected Output (terminal):
#                     quarter  units_sold  revenue  target  profit_margin  store_rating
# Region Product
# East   Home              Q1          60    15000   14000           22.0           3.8
#        Home              Q2          65    16250   15000           23.0           3.9

# %%
copy1_df.loc[('East', 'Home')]
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_840\541610842.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   copy1_df.loc[('East', 'Home')]
#                quarter  units_sold  revenue  target  profit_margin  \
# Region Product
# East   Home         Q1          60    15000   14000           22.0
#        Home         Q2          65    16250   15000           23.0
#
#                 store_rating
# Region Product
# East   Home              3.8
#        Home              3.9

# %% [markdown]
# Problem 7 – Select a Specific Element Using a Full Tuple
# Task:
# Using the MultiIndexed DataFrame, select and print the revenue value for the row where Region = 'West', Product = 'Sports', and quarter = 'Q2'. (First set quarter as part of the index, or use .loc[] with all three levels.)
#
# Pandas Concept Used:
# Advanced indexing with .loc[] specifying all levels
#
# # Expected Output (terminal):
# 13800

# %%
test_7_1 = copy1_df.loc[('West', 'Sports')]

test_7_2 = test_7_1[test_7_1.quarter == 'Q2']

print(test_7_2.iloc[0, 2])
# Out:
# 13800
# C:\Users\Admin\AppData\Local\Temp\ipykernel_840\3086878583.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   test_7_1 = copy1_df.loc[('West', 'Sports')]

# %% [markdown]
# Problem 8 – Slice Rows Between Two First-Level Labels
# Task:
# Using the MultiIndexed DataFrame, slice all rows from Region = 'South' through Region = 'West' (inclusive). Print the result.
#
# Pandas Concept Used:
# Slicing with .loc[] on MultiIndex
#
# # Expected Output (terminal):
#                     quarter  units_sold  revenue  target  profit_margin  store_rating
# Region Product
# South  Electronics       Q1          85    25500   24000           21.0           3.9
#        Electronics       Q2          90    27000   25000           22.0           4.0
#        Clothing          Q1         155    11625   10500           17.0           4.2
#        Clothing          Q2         160    12000   11000           18.0           4.3
#        Food              Q1         255     7650    7200           11.5           3.7
#        Food              Q2         260     7800    7400           12.5           3.9
#        Home              Q1          65    16250   15000           24.0           4.1
#        Home              Q2          70    17500   16000           25.0           4.2
#        Sports            Q1         105    12600   11500           18.5           3.8
#        Sports            Q2         110    13200   12000           19.5           3.9
# West   Electronics       Q1          85    25500   23000           21.5           4.1
#        Electronics       Q2          95    28500   26000           23.0           4.3
#        Clothing          Q1         155    11625   10500           17.0           4.0
#        Clothing          Q2         165    12375   11200           18.5           4.2
#        Food              Q1         255     7650    7000           11.5           3.8
#        Food              Q2         265     7950    7300           12.5           4.0
#        Home              Q1          65    16250   15000           24.0           4.0
#        Home              Q2          75    18750   17000           25.5           4.2
#        Sports            Q1         105    12600   11500           18.5           3.9
#        Sports            Q2         115    13800   12500           19.5           4.1

# %%
print(copy1_df.loc[(['South','West'])])
# Out:
#                    quarter  units_sold  revenue  target  profit_margin  \
# Region Product
# South  Electronics      Q1          85    25500   24000           21.0
#        Electronics      Q2          90    27000   25000           22.0
#        Clothing         Q1         155    11625   10500           17.0
#        Clothing         Q2         160    12000   11000           18.0
#        Food             Q1         255     7650    7200           11.5
#        Food             Q2         260     7800    7400           12.5
#        Home             Q1          65    16250   15000           24.0
#        Home             Q2          70    17500   16000           25.0
#        Sports           Q1         105    12600   11500           18.5
#        Sports           Q2         110    13200   12000           19.5
# West   Electronics      Q1          85    25500   23000           21.5
#        Electronics      Q2          95    28500   26000           23.0
# ...

# %% [markdown]
# Problem 9 – Boolean Indexing on a MultiIndexed DataFrame
# Task:
# Using the MultiIndexed DataFrame, filter and print only rows where units_sold > 150.
#
# Pandas Concept Used:
# Boolean indexing with MultiIndex — creating a mask and applying it
#
# # Expected Output (terminal):
#                     quarter  units_sold  revenue  target  profit_margin  store_rating
# Region Product
# North  Clothing          Q1         160    12000   11000           18.0           3.8
#        Clothing          Q2         170    12750   11500           16.5           3.9
#        Food              Q1         260     7800    7500           12.0           4.0
#        Food              Q2         270     8100    7800           13.5           4.2
# South  Clothing          Q1         155    11625   10500           17.0           4.2
#        Clothing          Q2         160    12000   11000           18.0           4.3
#        Food              Q1         255     7650    7200           11.5           3.7
#        Food              Q2         260     7800    7400           12.5           3.9
# East   Clothing          Q2         155    11625   10500           17.0           4.2
#        Food              Q1         250     7500    7000           10.0           3.5
#        Food              Q2         255     7650    7200           11.0           3.6
# West   Clothing          Q1         155    11625   10500           17.0           4.0
#        Clothing          Q2         165    12375   11200           18.5           4.2
#        Food              Q1         255     7650    7000           11.5           3.8
#        Food              Q2         265     7950    7300           12.5           4.0

# %% [markdown]
# Problem 10 – Sort a MultiIndexed DataFrame
# Task:
# Using the original flat DataFrame df (no MultiIndex yet), create a MultiIndex from region and quarter. Then sort the DataFrame by the MultiIndex using sort_index(). Print the first 8 rows.
#
# Pandas Concept Used:
# DataFrame.sort_index() on MultiIndex
#
# # Expected Output (terminal):
#                       product_category  units_sold  revenue  target  profit_margin  store_rating
# region quarter
# East   Q1                  Electronics          80    24000   22000           20.0           4.0
#        Q1                     Clothing         150    11250   10000           16.0           4.0
#        Q1                         Food         250     7500    7000           10.0           3.5
#        Q1                         Home          60    15000   14000           22.0           3.8
#        Q1                       Sports         100    12000   11000           17.5           3.7
#        Q2                  Electronics          85    25500   23500           21.5           4.1
#        Q2                     Clothing         155    11625   10500           17.0           4.2
#        Q2                         Food         255     7650    7200           11.0           3.6

# %% [markdown]
# Problem 11 – Sort MultiIndex by a Specific Level
# Task:
# Using the MultiIndexed DataFrame from Problem 10 (indexed by region and quarter), sort only by the second level (quarter) using sort_index(level=1). Print the first 8 rows.
#
# Pandas Concept Used:
# DataFrame.sort_index(level=n)
#
# # Expected Output (terminal):
#                       product_category  units_sold  revenue  target  profit_margin  store_rating
# region quarter
# East   Q1                  Electronics          80    24000   22000           20.0           4.0
#        Q1                     Clothing         150    11250   10000           16.0           4.0
#        Q1                         Food         250     7500    7000           10.0           3.5
#        Q1                         Home          60    15000   14000           22.0           3.8
#        Q1                       Sports         100    12000   11000           17.5           3.7
# North  Q1                  Electronics          90    27000   25000           22.5           4.2
#        Q1                     Clothing         160    12000   11000           18.0           3.8
#        Q1                         Food         260     7800    7500           12.0           4.0

# %% [markdown]
# Problem 12 – Rename Specific Index Labels Using rename()
# Task:
# Using the MultiIndexed DataFrame from Problem 1 (indexed by Region and Product), rename the 'Electronics' label in the second level to 'Tech' using df.rename(index={...}, level=...). Print the first 5 rows to confirm the change.
#
# Pandas Concept Used:
# DataFrame.rename(index=dict) with MultiIndex level
#
# # Expected Output (terminal):
#                     quarter  units_sold  revenue  target  profit_margin  store_rating
# Region Product
# North  Tech               Q1          90    27000   25000           22.5           4.2
#        Tech               Q2         100    30000   28000           24.1           4.5
#        Clothing           Q1         160    12000   11000           18.0           3.8
#        Clothing           Q2         170    12750   11500           16.5           3.9
#        Food               Q1         260     7800    7500           12.0           4.0

# %% [markdown]
# Problem 13 – Rename MultiIndex Level Names Using rename_axis()
# Task:
# Using the MultiIndexed DataFrame from Problem 1, rename the index axis names from 'Region' and 'Product' to 'Area' and 'Category' using rename_axis(). Print the first 5 rows to confirm.
#
# Pandas Concept Used:
# DataFrame.rename_axis()
#
# # Expected Output (terminal):
#                   quarter  units_sold  revenue  target  profit_margin  store_rating
# Area  Category
# North Electronics       Q1          90    27000   25000           22.5           4.2
#       Electronics       Q2         100    30000   28000           24.1           4.5
#       Clothing          Q1         160    12000   11000           18.0           3.8
#       Clothing          Q2         170    12750   11500           16.5           3.9
#       Food              Q1         260     7800    7500           12.0           4.0

# %% [markdown]
# Problem 14 – Apply Binary Comparison Operators to a Column
# Task:
# Using the original flat DataFrame df, apply the binary comparison operators (<, >, ==) to the units_sold column with the scalar value 100. Print the boolean Series for > (greater than 100) showing only the first 8 rows.
#
# Pandas Concept Used:
# Binary comparison operators (<, >, <=, >=, ==, !=)
#
# # Expected Output (terminal):
# 0     False
# 1     False
# 2      True
# 3      True
# 4      True
# 5      True
# 6     False
# 7     False
# Name: units_sold, dtype: bool

# %% [markdown]
# Problem 15 – Use Binary Comparison Functions
# Task:
# Using the revenue column of df, use the comparison functions lt(), gt(), and eq() to compare each value against 20000. Print the gt() result for the first 6 rows.
#
# Pandas Concept Used:
# Binary comparison functions (lt(), gt(), le(), ge(), eq(), ne())
#
# # Expected Output (terminal):
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# Name: revenue, dtype: bool

# %% [markdown]
# Problem 16 – Create a Boolean Index and Print It
# Task:
# Create a boolean index (mask) by checking which rows have profit_margin greater than 20.0. Print the resulting boolean Series for the first 10 rows.
#
# Pandas Concept Used:
# Creating a Boolean index with a conditional expression
#
# # Expected Output (terminal):
# 0     True
# 1     True
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# 7     True
# 8    False
# 9     True
# Name: profit_margin, dtype: bool

# %% [markdown]
# Problem 17 – Filter Rows Using a Boolean Mask
# Task:
# Using the boolean mask from Problem 16, filter the DataFrame to show only rows where profit_margin is greater than 20.0. Print the region, product_category, and profit_margin columns of the filtered result.
#
# Pandas Concept Used:
# Filtering data using boolean indexing
#
# # Expected Output (terminal):
#    region product_category  profit_margin
# 0   North     Electronics           22.5
# 1   North     Electronics           24.1
# 6   North            Home           25.0
# 7   North            Home           26.5
# 9   North          Sports           20.5
# 10  South     Electronics           21.0
# 11  South     Electronics           22.0
# 16  South            Home           24.0
# 17  South            Home           25.0
# 21   East     Electronics           21.5
# 26   East            Home           22.0
# 27   East            Home           23.0
# 30   West     Electronics           21.5
# 31   West     Electronics           23.0
# 36   West            Home           24.0
# 37   West            Home           25.5

# %% [markdown]
# Problem 18 – Filter with Multiple Conditions Using & (AND)
# Task:
# Filter the DataFrame to show rows where units_sold > 100 AND store_rating >= 4.0. Print the region, product_category, units_sold, and store_rating columns.
#
# Pandas Concept Used:
# Boolean indexing with multiple conditions using &
#
# # Expected Output (terminal):
#    region product_category  units_sold  store_rating
# 4   North            Food         260           4.0
# 5   North            Food         270           4.2
# 8   North          Sports         110           4.0
# 9   North          Sports         120           4.1
# 12  South        Clothing         155           4.2
# 13  South        Clothing         160           4.3
# 22   East        Clothing         150           4.0
# 23   East        Clothing         155           4.2
# 32   West        Clothing         155           4.0
# 33   West        Clothing         165           4.2
# 35   West            Food         265           4.0
# 39   West          Sports         115           4.1

# %% [markdown]
# Problem 19 – Filter Rows Using isin()
# Task:
# Filter the DataFrame to show only rows where product_category is in the list ['Electronics', 'Home']. Print the region, product_category, and revenue columns.
#
# Pandas Concept Used:
# Boolean masking with isin()
#
# # Expected Output (terminal):
#    region product_category  revenue
# 0   North     Electronics    27000
# 1   North     Electronics    30000
# 6   North            Home    17500
# 7   North            Home    20000
# 10  South     Electronics    25500
# 11  South     Electronics    27000
# 16  South            Home    16250
# 17  South            Home    17500
# 20   East     Electronics    24000
# 21   East     Electronics    25500
# 26   East            Home    15000
# 27   East            Home    16250
# 30   West     Electronics    25500
# 31   West     Electronics    28500
# 36   West            Home    16250
# 37   West            Home    18750

# %% [markdown]
# Problem 20 – Filter Using the NOT Operator (~)
# Task:
# Filter the DataFrame to show rows where region is NOT 'North'. Print the region, product_category, quarter, and units_sold columns. Show only the first 10 rows.
#
# Pandas Concept Used:
# Boolean masking with the ~ (NOT) operator
#
# # Expected Output (terminal):
#    region product_category quarter  units_sold
# 10  South     Electronics      Q1          85
# 11  South     Electronics      Q2          90
# 12  South        Clothing      Q1         155
# 13  South        Clothing      Q2         160
# 14  South            Food      Q1         255
# 15  South            Food      Q2         260
# 16  South            Home      Q1          65
# 17  South            Home      Q2          70
# 18  South          Sports      Q1         105
# 19  South          Sports      Q2         110
