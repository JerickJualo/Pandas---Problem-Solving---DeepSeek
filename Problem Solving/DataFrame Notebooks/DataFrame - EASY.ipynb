# %%
import pandas as pd
import numpy as np

dataframe_df = pd.read_csv(r'C:\Users\User\OneDrive\Documents\Pandas - Problem Solving - DeepSeek\Data Sets\employee_records_2024.csv')

# %% [markdown]
# File name: employee_records_2024.csv
#
# Description:
#
# This dataset contains information about employees in a small company, including their department, salary, bonus, and hire date. The dataset has 50 rows and is designed to give you plenty of data to practice the DataFrame concepts from the links.

# %% [markdown]
# Problem 1 – Create a DataFrame from a CSV File
# Task:
# Read the employee_records_2024.csv file into a Pandas DataFrame named df. Print the DataFrame.
#
# Pandas Concept Used:
# pd.read_csv() to load data into a DataFrame.
#
# # Expected Output (terminal):
#     emp_id           name   department  salary  bonus   hire_date
# 0     E001  Alice Johnson        Sales   55000   5000  2022-03-15
# 1     E002      Bob Smith  Engineering   72000   8000  2021-08-10
# 2     E003    Carol Davis    Marketing   61000   4500  2023-01-20
# 3     E004   David Wilson        Sales   53000   3500  2022-11-05
# 4     E005      Eva Brown  Engineering   78000   9500  2020-06-12
# 5     E006    Frank Miller           HR   49000   2000  2023-09-18
# ..     ...           ...       ...       ...     ..        ...
# 41    E042    Paula Shaw        Sales   58000   4300  2023-01-05
# 42    E043  Quentin Bell  Engineering   75000   9000  2021-06-14
# 43    E044    Rosa Gomez           HR   50000   2100  2023-09-02
# 44    E045    Steve Ford        Sales   63000   5700  2022-06-21
# 45    E046    Tara Woods  Engineering   78000   9500  2020-09-15
# 46    E047  Ulysses Stone    Marketing   69000   5800  2021-11-08
# 47    E048   Violet Ray        Sales   59000   4500  2023-02-27
# 48    E049  Wayne Knight  Engineering   81000  10400  2019-05-12
# 49    E050   Yara Mendez           HR   51000   2200  2023-12-29

# %%
print(dataframe_df)
# Out:
#    emp_id            name   department  salary  bonus   hire_date
# 0    E001   Alice Johnson        Sales   55000   5000   3/15/2022
# 1    E002       Bob Smith  Engineering   72000   8000   8/10/2021
# 2    E003     Carol Davis    Marketing   61000   4500   1/20/2023
# 3    E004    David Wilson        Sales   53000   3500   11/5/2022
# 4    E005       Eva Brown  Engineering   78000   9500   6/12/2020
# 5    E006    Frank Miller           HR   49000   2000   9/18/2023
# 6    E007       Grace Lee    Marketing   64000   5200   12/1/2021
# 7    E008     Henry Clark        Sales   56000   4000   7/22/2022
# 8    E009      Ivy Taylor  Engineering   81000  10500   4/30/2019
# 9    E010   Jack Martinez           HR   51000   2200   2/14/2023
# 10   E011     Kelly White        Sales   58000   4500    9/9/2022
# 11   E012    Leo Anderson  Engineering   75000   9000   5/17/2021
# 12   E013      Mia Thomas    Marketing   62000   4800  12/25/2022
# ...

# %% [markdown]
# Problem 2 – Display the First 5 Rows of the DataFrame
# Task:
# Using the df DataFrame from Problem 1, print only the first five rows.
#
# Pandas Concept Used:
# DataFrame.head() method.
#
# # Expected Output (terminal):
#    emp_id           name   department  salary  bonus   hire_date
# 0    E001  Alice Johnson        Sales   55000   5000  2022-03-15
# 1    E002      Bob Smith  Engineering   72000   8000  2021-08-10
# 2    E003    Carol Davis    Marketing   61000   4500  2023-01-20
# 3    E004   David Wilson        Sales   53000   3500  2022-11-05
# 4    E005      Eva Brown  Engineering   78000   9500  2020-06-12

# %%
print(dataframe_df.head(5))
# Out:
#   emp_id           name   department  salary  bonus  hire_date
# 0   E001  Alice Johnson        Sales   55000   5000  3/15/2022
# 1   E002      Bob Smith  Engineering   72000   8000  8/10/2021
# 2   E003    Carol Davis    Marketing   61000   4500  1/20/2023
# 3   E004   David Wilson        Sales   53000   3500  11/5/2022
# 4   E005      Eva Brown  Engineering   78000   9500  6/12/2020

# %% [markdown]
# Problem 3 – Display the Last 3 Rows of the DataFrame
# Task:
# Using the df DataFrame, print only the last three rows.
#
# Pandas Concept Used:
# DataFrame.tail() method.
#
# # Expected Output (terminal):
#     emp_id          name   department  salary  bonus   hire_date
# 47    E048    Violet Ray        Sales   59000   4500  2023-02-27
# 48    E049  Wayne Knight  Engineering   81000  10400  2019-05-12
# 49    E050   Yara Mendez           HR   51000   2200  2023-12-29

# %%
print(dataframe_df.tail(3))
# Out:
#    emp_id          name   department  salary  bonus   hire_date
# 47   E048    Violet Ray        Sales   59000   4500   2/27/2023
# 48   E049  Wayne Knight  Engineering   81000  10400   5/12/2019
# 49   E050   Yara Mendez           HR   51000   2200  12/29/2023

# %% [markdown]
# Problem 4 – Get the Shape (Dimensions) of the DataFrame
# Task:
# Print the shape of the df DataFrame as a tuple (rows, columns).
#
# Pandas Concept Used:
# DataFrame.shape attribute.
#
# # Expected Output (terminal):
# (50, 6)

# %%
print(dataframe_df.shape)
# Out:
# (50, 6)

# %% [markdown]
# Problem 5 – Get Summary Information About the DataFrame
# Task:
# Print the concise summary of the df DataFrame, including the data types and memory usage.
#
# Pandas Concept Used:
# DataFrame.info() method.
#
# # Expected Output (terminal):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     object
#  1   name        50 non-null     object
#  2   department  50 non-null     object
#  3   salary      50 non-null     int64
#  4   bonus       50 non-null     int64
#  5   hire_date   50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB

# %%
print(dataframe_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   emp_id      50 non-null     object
#  1   name        50 non-null     object
#  2   department  50 non-null     object
#  3   salary      50 non-null     int64
#  4   bonus       50 non-null     int64
#  5   hire_date   50 non-null     object
# dtypes: int64(2), object(4)
# memory usage: 2.5+ KB
# None

# %% [markdown]
# Problem 6 – Access the Row Index Labels
# Task:
# Print the row index labels (the index object) of the df DataFrame.
#
# Pandas Concept Used:
# DataFrame.index attribute.
#
# # Expected Output (terminal):
# RangeIndex(start=0, stop=50, step=1)

# %%
print(dataframe_df.index)
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %% [markdown]
# Problem 7 – Access the Column Labels
# Task:
# Print the column labels of the df DataFrame.
#
# Pandas Concept Used:
# DataFrame.columns attribute.
#
# # Expected Output (terminal):
# Index(['emp_id', 'name', 'department', 'salary', 'bonus', 'hire_date'], dtype='object')

# %%
print(dataframe_df.columns)
# Out:
# Index(['emp_id', 'name', 'department', 'salary', 'bonus', 'hire_date'], dtype='object')

# %% [markdown]
# Problem 8 – Select a Single Column as a Series
# Task:
# Select the salary column from the df DataFrame and print it. (The output will be a Pandas Series.)
#
# Pandas Concept Used:
# Selecting a column using df['column_name'].
#
# # Expected Output (terminal):
# 0     55000
# 1     72000
# 2     61000
# 3     53000
# 4     78000
# 5     49000
# 6     64000
# .      ...
# 41    58000
# 42    75000
# 43    50000
# 44    63000
# 45    78000
# 46    69000
# 47    59000
# 48    81000
# 49    51000
# Name: salary, dtype: int64

# %%
salary_column = dataframe_df['salary']
print(salary_column)
# Out:
# 0     55000
# 1     72000
# 2     61000
# 3     53000
# 4     78000
# 5     49000
# 6     64000
# 7     56000
# 8     81000
# 9     51000
# 10    58000
# 11    75000
# 12    62000
# 13    54000
# 14    79000
# 15    47000
# 16    66000
# 17    57000
# 18    73000
# 19    50000
# 20    59000
# 21    76000
# 22    63000
# 23    55000
# 24    80000
# 25    48000
# 26    61000
# 27    77000
# 28    65000
# 29    56000
# 30    82000
# 31    52000
# 32    60000
# 33    74000
# 34    67000
# 35    57000
# 36    79000
# 37    49000
# 38    62000
# 39    83000
# 40    68000
# 41    58000
# 42    75000
# 43    50000
# 44    63000
# 45    78000
# 46    69000
# 47    59000
# 48    81000
# 49    51000
# Name: salary, dtype: int64

# %% [markdown]
# Problem 9 – Select Multiple Columns
# Task:
# Select the name and salary columns from the df DataFrame and print the resulting DataFrame.
#
# Pandas Concept Used:
# Selecting multiple columns using df[['col1', 'col2']].
#
# # Expected Output (terminal):
#               name  salary
# 0    Alice Johnson   55000
# 1        Bob Smith   72000
# 2      Carol Davis   61000
# 3     David Wilson   53000
# 4        Eva Brown   78000
# 5     Frank Miller   49000
# 6        Grace Lee   64000
# .         ...         ...
# 41      Paula Shaw   58000
# 42    Quentin Bell   75000
# 43      Rosa Gomez   50000
# 44      Steve Ford   63000
# 45      Tara Woods   78000
# 46    Ulysses Stone   69000
# 47      Violet Ray   59000
# 48    Wayne Knight   81000
# 49     Yara Mendez   51000

# %%
print(dataframe_df[['name','salary']])
# Out:
#               name  salary
# 0    Alice Johnson   55000
# 1        Bob Smith   72000
# 2      Carol Davis   61000
# 3     David Wilson   53000
# 4        Eva Brown   78000
# 5     Frank Miller   49000
# 6        Grace Lee   64000
# 7      Henry Clark   56000
# 8       Ivy Taylor   81000
# 9    Jack Martinez   51000
# 10     Kelly White   58000
# 11    Leo Anderson   75000
# 12      Mia Thomas   62000
# 13     Nick Harris   54000
# 14   Olivia Martin   79000
# 15  Paul Rodriguez   47000
# 16     Quinn Lewis   66000
# 17     Rita Walker   57000
# 18       Sam Young   73000
# 19       Tina Hall   50000
# 20       Umar Khan   59000
# 21      Vera Adams   76000
# 22      Will Scott   63000
# 23      Xena Brown   55000
# 24     Yosef Green   80000
# 25      Zara Ahmed   48000
# 26     Alan Parker   61000
# 27     Beth Carter   77000
# 28      Carl Evans   65000
# 29    Diana Flores   56000
# 30       Eric Gray   82000
# 31      Fiona Reed   52000
# 32     George Hill   60000
# ...

# %% [markdown]
# Problem 10 – Select Rows by Integer Position (.iloc)
# Task:
# Using .iloc[], select and print the first three rows (positions 0, 1, and 2) of the df DataFrame.
#
# Pandas Concept Used:
# DataFrame.iloc[start:end] for position‑based slicing.
#
# # Expected Output (terminal):
#    emp_id           name   department  salary  bonus   hire_date
# 0    E001  Alice Johnson        Sales   55000   5000  2022-03-15
# 1    E002      Bob Smith  Engineering   72000   8000  2021-08-10
# 2    E003    Carol Davis    Marketing   61000   4500  2023-01-20

# %%
first_three_rows = dataframe_df.iloc[:3,:]
print(first_three_rows)
# Out:
#   emp_id           name   department  salary  bonus  hire_date
# 0   E001  Alice Johnson        Sales   55000   5000  3/15/2022
# 1   E002      Bob Smith  Engineering   72000   8000  8/10/2021
# 2   E003    Carol Davis    Marketing   61000   4500  1/20/2023

# %% [markdown]
# Problem 11 – Select Rows and Columns by Integer Position (.iloc)
# Task:
# Using .iloc[], select and print the value at row position 4 and column position 3 (which is the salary column).
#
# Pandas Concept Used:
# DataFrame.iloc[row_position, column_position] to access a single cell.
#
# # Expected Output (terminal):
# 78000

# %%
print(dataframe_df.iloc[4,3])
# Out:
# 78000

# %% [markdown]
# Problem 12 – Select Rows by Label (.loc)
# Task:
# Using .loc[], select and print the row with index label 10.
#
# Pandas Concept Used:
# DataFrame.loc[label] for label‑based selection.
#
# # Expected Output (terminal):
# emp_id                E011
# name           Kelly White
# department           Sales
# salary               58000
# bonus                 4500
# hire_date       2022-09-09
# Name: 10, dtype: object

# %%
print(dataframe_df.loc[10,:])
# Out:
# emp_id               E011
# name          Kelly White
# department          Sales
# salary              58000
# bonus                4500
# hire_date        9/9/2022
# Name: 10, dtype: object

# %% [markdown]
# Problem 13 – Rename a Column
# Task:
# Create a copy of the df DataFrame called df_renamed. Rename the column salary to base_salary. Print the modified DataFrame's columns to verify the change.
#
# Pandas Concept Used:
# DataFrame.rename(columns={'old_name': 'new_name'}) method.
#
# # Expected Output (terminal):
# Index(['emp_id', 'name', 'department', 'base_salary', 'bonus', 'hire_date'], dtype='object')

# %%
df_renamed = dataframe_df.copy().rename(columns={'salary': 'base_salary'})
print(df_renamed.columns)
# Out:
# Index(['emp_id', 'name', 'department', 'base_salary', 'bonus', 'hire_date'], dtype='object')

# %% [markdown]
# Problem 14 – Add a New Column to the DataFrame
# Task:
# Add a new column named total_compensation to the df DataFrame, which is the sum of salary and bonus. Then print the first five rows of the updated DataFrame.
#
# Pandas Concept Used:
# Direct assignment to a new column name df['new_col'] = values.
#
# # Expected Output (terminal):
#    emp_id           name   department  salary  bonus   hire_date  total_compensation
# 0    E001  Alice Johnson        Sales   55000   5000  2022-03-15               60000
# 1    E002      Bob Smith  Engineering   72000   8000  2021-08-10               80000
# 2    E003    Carol Davis    Marketing   61000   4500  2023-01-20               65500
# 3    E004   David Wilson        Sales   53000   3500  2022-11-05               56500
# 4    E005      Eva Brown  Engineering   78000   9500  2020-06-12               87500

# %%
dataframe_df['total_compensation'] = dataframe_df['salary'] + dataframe_df['bonus']

print(dataframe_df.head())
# Out:
#   emp_id           name   department  salary  bonus  hire_date  \
# 0   E001  Alice Johnson        Sales   55000   5000  3/15/2022
# 1   E002      Bob Smith  Engineering   72000   8000  8/10/2021
# 2   E003    Carol Davis    Marketing   61000   4500  1/20/2023
# 3   E004   David Wilson        Sales   53000   3500  11/5/2022
# 4   E005      Eva Brown  Engineering   78000   9500  6/12/2020
#
#    total_compensation
# 0               60000
# 1               80000
# 2               65500
# 3               56500
# 4               87500

# %% [markdown]
# Problem 15 – Perform Scalar Arithmetic on a DataFrame Column
# Task:
# Print the salary column multiplied by 1.1 (to simulate a 10% salary increase). The output should show the original and the increased salary values.
#
# Pandas Concept Used:
# Element‑wise arithmetic df['column'] * scalar.
#
# # Expected Output (terminal):
# 0     55000.0
# 1     72000.0
# 2     61000.0
# 3     53000.0
# 4     78000.0
# 5     49000.0
# .      ...
# 41    58000.0
# 42    75000.0
# 43    50000.0
# 44    63000.0
# 45    78000.0
# 46    69000.0
# 47    59000.0
# 48    81000.0
# 49    51000.0
# Name: salary, dtype: float64

# %%
salary_increase = dataframe_df['salary'] * 1.01
print(salary_increase)
# Out:
# 0     55550.0
# 1     72720.0
# 2     61610.0
# 3     53530.0
# 4     78780.0
# 5     49490.0
# 6     64640.0
# 7     56560.0
# 8     81810.0
# 9     51510.0
# 10    58580.0
# 11    75750.0
# 12    62620.0
# 13    54540.0
# 14    79790.0
# 15    47470.0
# 16    66660.0
# 17    57570.0
# 18    73730.0
# 19    50500.0
# 20    59590.0
# 21    76760.0
# 22    63630.0
# 23    55550.0
# 24    80800.0
# 25    48480.0
# 26    61610.0
# 27    77770.0
# 28    65650.0
# 29    56560.0
# 30    82820.0
# 31    52520.0
# 32    60600.0
# 33    74740.0
# 34    67670.0
# 35    57570.0
# 36    79790.0
# 37    49490.0
# 38    62620.0
# 39    83830.0
# 40    68680.0
# 41    58580.0
# 42    75750.0
# 43    50500.0
# 44    63630.0
# 45    78780.0
# 46    69690.0
# 47    59590.0
# 48    81810.0
# 49    51510.0
# Name: salary, dtype: float64
